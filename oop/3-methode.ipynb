# %%
class Product:
    id = 0

    def __init__(self,name,price):
        self.name = name
        self.price = price
        Product.id += 1
        

    def find_product_service(name):
        product1 = Product("Teh Botol",15000)
        product2 = Product("Teh Kotak",12000)

        if (product1.name == name):
            return product1
        if (product2.name == name):
            return product2 

        return None


# print(Product.find_product_service("Teh Kotak1").name)

result = Product.find_product_service("Teh Kotak")
if (result):
    print(result.name)
else:
    print("tidak ketemu")

# product1 = Product("Teh Kotak",15000)
# product2 = Product("Teh Susu",18000)
# result = Product.find_product_service("Teh Kotak")
# if (result):
#     print(result.name)
# else:
#     print("tidak ketemu")
# Out:
# Teh Kotak

# %%
class Product:
    id = 0

    def __init__(self,name,price):
        self.name = name
        self.price = price
        Product.id += 1
        
    def find_product_service(name):
        product1 = Product("Teh Botol",15000)
        product2 = Product("Teh Kotak",12000)

        if (product1.name == name):
            return product1
        if (product2.name == name):
            return product2 

        return None
    
    def 


#print(Product.find_product_service("Teh Kotak1").name)

result = Product.find_product_service("Teh Kotak")
if (result):
    print(result.name)
else:
    print("tidak ketemu")

# %%
import json
class Product:
    id = 0

    def __init__(self,name,price):
        self.name = name
        self.price = price
        Product.id += 1
        
    def find_product_service(name):
        product1 = Product("Teh Botol",15000)
        product2 = Product("Teh Kotak",12000)

        if (product1.name == name):
            return product1
        if (product2.name == name):
            return product2 

        return None
    
    def buy_product_service(name,qty):
        product1 = Product("Teh Botol",15000)
        product2 = Product("Teh Kotak",12000)

        product_dibeli = None

        if (product1.name == name):
            product_dibeli = product1
            hasil_beli = [(product_dibeli,qty)]
            return hasil_beli
        if (product2.name == name):
            product_dibeli = product2
            hasil_beli = [(product_dibeli,qty)]
            return hasil_beli

        return None
    

    

#print(Product.find_product_service("Teh Kotak1").name)

result = Product.buy_product_service("Teh Kotak",2)
if (result):
    product = result[0][0]
    print(type(result))
    print(result[0][1])
else:
    print("tidak ketemu")
# Out:
# <class 'list'>
# 2

# %%
import json
keranjang_belanja = []

class Product:
    id = 0
    keranjang_belanja = []
    def __init__(self,name,price):
        self.name = name
        self.price = price
        Product.id += 1
        
    def find_product_service(self,name):
        product1 = Product("Teh Botol",15000)
        product2 = Product("Teh Kotak",12000)

        if (product1.name == name):
            return product1
        if (product2.name == name):
            return product2 

        return None
    
    def buy_product_service(self,name,qty):
        product1 = Product("Teh Botol",15000)
        product2 = Product("Teh Kotak",12000)

        product_dibeli = None

        if (product1.name == name):
            product_dibeli = product1
            hasil_beli = [(product_dibeli,qty)]
            self.tambah_keranjang_belanja(hasil_beli)
            return hasil_beli
        if (product2.name == name):
            product_dibeli = product2
            hasil_beli = [(product_dibeli,qty)]
            self.tambah_keranjang_belanja(hasil_beli)
            return hasil_beli

        return None
    

    def tambah_keranjang_belanja(hasil_beli):
        keranjang_belanja.append(hasil_beli)



# result = Product.buy_product_service(Product,name="Teh Kotak",qty=2)
# if (result):
#     product = result[0][0]
#     print(product.name)
#     print(result[0][1])
# else:
#     print("tidak ketemu")


# result = Product.buy_product_service(Product,name="Teh Botol",qty=1)
# if (result):
#     product = result[0][0]
#     print(product.name)
#     print(result[0][1])
# else:
#     print("tidak ketemu")



class Pembeli:
    email = ""
    nama = ""
    hp = ""
    alamat = ""

    def beli(self,product,qtty):
        product1 = product
        pembelian = [(product1,qtty)]
        # print(pembelian)
        return pembelian


product = Product("Teh Botol",15000)
pembeli1 = Pembeli()
hasil_pembelian = pembeli1.beli(product=product,qtty=2)
producttest = hasil_pembelian
print(type(producttest))


class Penjual:
    email = ""
    nama = ""
    hp = ""
    alamat = ""

    def jual(self,product,qtty):
        product1 = product
        penjualan = [(product1,qtty)]
        # print(pembelian)
        return penjualan

product = Product("Teh Botol",15000)
penjual1 = Penjual()
hasil_penjualan = penjual1.jual(product=product,qtty=2)
print(hasil_penjualan[0][1])
# Out:
# <class 'list'>
# 2
